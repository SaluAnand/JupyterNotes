# %%
dic = {"value1":1 , "value2":2 , "value3":3}
for i in dic :
    print("key " + i + " and Value is " + str(dic[i]))
print(dic)
print(dic.keys())

# if we give dduplicate keys it will over ride the old key value

dic1 = {"value1":1 , "value2":2 , "value1":3}
print(dic1)

#give any value as key
dic2 = {0:1 , "one":2 , True:3 , 1:4} 
print(dic2)

#list as key and value will give error

#dic3 = {["one" , "two"]:1}
#print(dic3)
#dic4 = {1:["one" , "two"]}
#print(dic4)
dic5 = {1:("one" , "two")}
print(dic5)

print("------------------------------")
dic1 = {"value1":1 , "value2":2 , "value1":3}
print(dic1)
dic1["value3"] = 4
print(dic1)
print("value3" in dic1)
del(dic1["value3"])
print(dic1)
dic1["value2"] = 4
print(dic1)
keys = dic1.keys()
print(keys)
values = dic1.values()
print(values)
list = dic1.keys()
print(list)

print("------------------------------------------------")
doubledic = {"value1":{"value10":10 , "value11":11},
             "Value2":{"value20":20 , "value21":21}}
print(doubledic)
for i in doubledic :
    print (i)
print(doubledic.values())
print("----------------------------------------------")
for dic in doubledic.values() :
    print(dic)
    for key in dic :
        print(key)
        print (key + " " + str(dic[key]))
    print("-----------")
print(doubledic["value1"]["value10"])
newdata = {"value30":30 , "value31":31}
doubledic["Value3"] = newdata
print(doubledic)
print("----------------------------------------------")
for key,value in doubledic.items():
    print (key)
    print (values)
# Out:
# key value1 and Value is 1
# key value2 and Value is 2
# key value3 and Value is 3
# {'value1': 1, 'value2': 2, 'value3': 3}
# dict_keys(['value1', 'value2', 'value3'])
# {'value1': 3, 'value2': 2}
# {0: 1, 'one': 2, True: 4}
# {1: ('one', 'two')}
# ------------------------------
# {'value1': 3, 'value2': 2}
# {'value1': 3, 'value2': 2, 'value3': 4}
# True
# {'value1': 3, 'value2': 2}
# {'value1': 3, 'value2': 4}
# dict_keys(['value1', 'value2'])
# dict_values([3, 4])
# dict_keys(['value1', 'value2'])
# ------------------------------------------------
# {'value1': {'value10': 10, 'value11': 11}, 'Value2': {'value20': 20, 'value21': 21}}
# value1
# Value2
# dict_values([{'value10': 10, 'value11': 11}, {'value20': 20, 'value21': 21}])
# ----------------------------------------------
# {'value10': 10, 'value11': 11}
# value10
# value10 10
# value11
# value11 11
# -----------
# {'value20': 20, 'value21': 21}
# value20
# value20 20
# value21
# value21 21
# -----------
# 10
# ...
